# %%
! pip install huggingface_hub
! git clone https://github.com/ggerganov/llama.cpp.git
! pip install -r llama.cpp/requirements.txt
# Out:
# ...
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 20532, done.
# remote: Counting objects: 100% (7592/7592), done.
# remote: Compressing objects: 100% (535/535), done.
# remote: Total 20532 (delta 7376), reused 7082 (delta 7057), pack-reused 12940
# Receiving objects: 100% (20532/20532), 23.72 MiB | 12.04 MiB/s, done.
# Resolving deltas: 100% (14552/14552), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 63.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 33.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 55.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 54.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 76.3 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import snapshot_download

model_id="Vasanth/mistral-sql"
snapshot_download(repo_id=model_id, local_dir="mymodel-hf",
                  local_dir_use_symlinks=False, revision="main")
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# (…)f54220e8e5d04222df696f4cf/.gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# (…)3cff54220e8e5d04222df696f4cf/config.json:   0%|          | 0.00/631 [00:00<?, ?B/s]
# (…)5d04222df696f4cf/special_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# (…)e5d04222df696f4cf/generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# (…)22df696f4cf/pytorch_model.bin.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# (…)f54220e8e5d04222df696f4cf/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# (…)8e5d04222df696f4cf/tokenizer_config.json:   0%|          | 0.00/731 [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# '/content/mycopilot-hf'

# %%
! python llama.cpp/convert.py mymodel-hf \
  --outfile mydatabase-admin.gguf \
  --outtype q8_0
# Out:
# Loading model file mymistral-hf/pytorch_model-00001-of-00002.bin
# Loading model file mymistral-hf/pytorch_model-00001-of-00002.bin
# Loading model file mymistral-hf/pytorch_model-00002-of-00002.bin
# params = Params(n_vocab=32000, n_embd=4096, n_layer=32, n_ctx=32768, n_ff=14336, n_head=32, n_head_kv=8, f_norm_eps=1e-05, rope_scaling_type=None, f_rope_freq_base=10000.0, f_rope_scale=None, n_orig_ctx=None, rope_finetuned=None, ftype=<GGMLFileType.MostlyQ8_0: 7>, path_model=PosixPath('mymistral-hf'))
# Loading vocab file 'mymistral-hf/tokenizer.model', type 'spm'
# Permuting layer 0
# Permuting layer 1
# Permuting layer 2
# Permuting layer 3
# Permuting layer 4
# Permuting layer 5
# Permuting layer 6
# Permuting layer 7
# Permuting layer 8
# Permuting layer 9
# Permuting layer 10
# Permuting layer 11
# Permuting layer 12
# Permuting layer 13
# Permuting layer 14
# Permuting layer 15
# Permuting layer 16
# Permuting layer 17
# Permuting layer 18
# Permuting layer 19
# ...

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from huggingface_hub import HfApi
api = HfApi()

model_id = "Vasanth/database-admin"
api.create_repo(model_id, exist_ok=True, repo_type="model")
api.upload_file(
    repo_id=model_id,
    path_or_fileobj="mycopilot-codellama.gguf",
    path_in_repo="mycopilot-codellama.gguf"
)
# Out:
# mycopilot-codellama.gguf:   0%|          | 0.00/7.70G [00:00<?, ?B/s]
# 'https://huggingface.co/Vasanth/copilot-codellama-7b.gguf/blob/main/mycopilot-codellama.gguf'
