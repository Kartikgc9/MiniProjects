# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os
print(os.listdir())

import warnings
# Out:
# ['mycsvfile.csv', '.virtual_documents', '__notebook_source__.ipynb']

# %%
df_heart = pd.read_csv("/kaggle/input/thapar/Train_dataset.csv")

# %%
type(df_heart)
# Out:
# pandas.core.frame.DataFrame

# %%
df_heart.shape
# Out:
# (242, 15)

# %%
df_heart.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output', 'patient_id'],
#       dtype='object')

# %%
df_heart.head(5)
# 1 for male(sex)
#0 for female(sex)
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   57    1   0     150   276    0        0       112     1      0.6    1
# 1   59    1   3     170   288    0        0       159     0      0.2    1
# 2   57    1   2     150   126    1        1       173     0      0.2    2
# 3   56    0   0     134   409    0        0       150     1      1.9    1
# 4   71    0   2     110   265    1        0       130     0      0.0    2
#
#    caa  thall  output  patient_id
# 0    1      1       0         179
# 1    0      3       0         228
# 2    1      3       1         111
# 3    2      3       0         246
# 4    1      2       1          60

# %%
df_heart.sample(5)
#1 means patient is suffering from heart disease.
# 0 means not suffering.
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 14    46    0   1     105   204    0        1       172     0      0.0    2
# 34    66    0   3     150   226    0        1       114     0      2.6    0
# 167   46    0   2     142   177    0        0       160     1      1.4    0
# 57    50    1   2     129   196    0        1       163     0      0.0    2
# 234   39    1   0     118   219    0        1       140     0      1.2    1
#
#      caa  thall  output  patient_id
# 14     0      2       1         118
# 34     0      2       1          17
# 167    0      2       1          35
# 57     0      2       1         104
# 234    0      3       0         212

# %%
print("Total No of disease")
print(len(df_heart.output.unique()))
# Out:
# Total No of disease
# 2

# %%
df_heart["output"].unique()
#0 for no disease.
#1 for heart disease.
# Out:
# array([0, 1])

# %%
df_heart.groupby('output').size()
#0 for no disease.
#1 for heart disease.
# Out:
# output
# 0    109
# 1    133
# dtype: int64

# %%
df_heart["output"].value_counts()
# Out:
# 1    133
# 0    109
# Name: output, dtype: int64

# %%
# Visualization of the frequency distribution.
f , ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="output" , data=df_heart)
plt.show()

# %%
df_heart.groupby('sex')['output'].value_counts()
# 1 for male(sex)
#0 for female(sex)
# Out:
# sex  output
# 0    1         58
#      0         18
# 1    0         91
#      1         75
# Name: output, dtype: int64

# %%
f , ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="sex" ,hue="output" ,data=df_heart)
plt.show()

# %%
ax = sns.catplot(x ="output" ,col="sex" ,data=df_heart ,kind="count" ,height=5 ,aspect=1)

# %%
df.to_csv('mycsvfile.csv',index=False)
